# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
HDFC_df = yf.download('HDFCBANK.NS', 
                      start='2023-02-15', 
                      end='2023-05-12', 
)
##print(HDFC_df)
HDFC_df['Close'].plot(figsize=(25,8))
HDFC_df['Close'].rolling(window=5).mean().plot()
HDFC_df['Close'].ewm(span=3, adjust=True).mean().plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <Axes: xlabel='Date'>
